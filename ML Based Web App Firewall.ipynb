# %%
import pandas as pd
http_request_df = pd.read_csv("processed_urls.csv")

# %%
from pycaret.classification import *
from sklearn.model_selection import train_test_split

# %%
train_set, test_set = train_test_split(http_request_df.loc[:8000,:])

# %%
clu1 = setup(data = train_set, target='type', \
             numeric_features=['unicode', 'inequality', 'pipe', 'semicolon', 'curlybrace', 'caret', 'consecutive_num', 'hyphen', 'underscore'])
# Out:
# <style  type="text/css" >
# #T_cf77c_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_cf77c_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_cf77c_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_cf77c_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_cf77c_row0_col1" class="data row0 col1" >1025</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_cf77c_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_cf77c_row1_col1" class="data row1 col1" >type</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_cf77c_row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_cf77c_row2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_cf77c_row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_cf77c_row3_col1" class="data row3 col1" >benign: 0, defacement: 1, malware: 2, phishing: 3</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_cf77c_row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_cf77c_row4_col1" class="data row4 col1" >(6000, 12)</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_cf77c_row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_cf77c_row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_cf77c_row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_cf77c_row6_col1" class="data row6 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_cf77c_row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_cf77c_row7_col1" class="data row7 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_cf77c_row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_cf77c_row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_cf77c_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_cf77c_row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_cf77c_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_cf77c_row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_cf77c_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_cf77c_row11_col1" class="data row11 col1" >(4199, 4201)</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_cf77c_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_cf77c_row12_col1" class="data row12 col1" >(1801, 4201)</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_cf77c_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_cf77c_row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_cf77c_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_cf77c_row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_cf77c_row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_cf77c_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_cf77c_row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_cf77c_row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_cf77c_row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_cf77c_row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row18" class="row_heading level0 row18" >18</th>
#                         <td id="T_cf77c_row18_col0" class="data row18 col0" >Use GPU</td>
#                         <td id="T_cf77c_row18_col1" class="data row18 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row19" class="row_heading level0 row19" >19</th>
#                         <td id="T_cf77c_row19_col0" class="data row19 col0" >Log Experiment</td>
#                         <td id="T_cf77c_row19_col1" class="data row19 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row20" class="row_heading level0 row20" >20</th>
#                         <td id="T_cf77c_row20_col0" class="data row20 col0" >Experiment Name</td>
#                         <td id="T_cf77c_row20_col1" class="data row20 col1" >clf-default-name</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row21" class="row_heading level0 row21" >21</th>
#                         <td id="T_cf77c_row21_col0" class="data row21 col0" >USI</td>
#                         <td id="T_cf77c_row21_col1" class="data row21 col1" >d460</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row22" class="row_heading level0 row22" >22</th>
#                         <td id="T_cf77c_row22_col0" class="data row22 col0" >Imputation Type</td>
#                         <td id="T_cf77c_row22_col1" class="data row22 col1" >simple</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_level0_row23" class="row_heading level0 row23" >23</th>
#                         <td id="T_cf77c_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#                         <td id="T_cf77c_row23_col1" class="data row23 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_cf77c_leve

# %%
best_model = compare_models()
# Out:
# <style  type="text/css" >
#     #T_48963_ th {
#           text-align: left;
#     }#T_48963_row0_col0,#T_48963_row0_col4,#T_48963_row1_col0,#T_48963_row1_col1,#T_48963_row1_col2,#T_48963_row1_col3,#T_48963_row1_col4,#T_48963_row1_col5,#T_48963_row1_col6,#T_48963_row1_col7,#T_48963_row2_col0,#T_48963_row2_col1,#T_48963_row2_col2,#T_48963_row2_col3,#T_48963_row2_col4,#T_48963_row2_col5,#T_48963_row2_col6,#T_48963_row2_col7,#T_48963_row3_col0,#T_48963_row3_col1,#T_48963_row3_col2,#T_48963_row3_col3,#T_48963_row3_col5,#T_48963_row3_col6,#T_48963_row3_col7,#T_48963_row4_col0,#T_48963_row4_col1,#T_48963_row4_col2,#T_48963_row4_col3,#T_48963_row4_col4,#T_48963_row4_col5,#T_48963_row4_col6,#T_48963_row4_col7,#T_48963_row5_col0,#T_48963_row5_col1,#T_48963_row5_col2,#T_48963_row5_col3,#T_48963_row5_col4,#T_48963_row5_col5,#T_48963_row5_col6,#T_48963_row5_col7,#T_48963_row6_col0,#T_48963_row6_col1,#T_48963_row6_col2,#T_48963_row6_col3,#T_48963_row6_col4,#T_48963_row6_col5,#T_48963_row6_col6,#T_48963_row6_col7,#T_48963_row7_col0,#T_48963_row7_col1,#T_48963_row7_col2,#T_48963_row7_col3,#T_48963_row7_col4,#T_48963_row7_col5,#T_48963_row7_col6,#T_48963_row7_col7,#T_48963_row8_col0,#T_48963_row8_col1,#T_48963_row8_col2,#T_48963_row8_col3,#T_48963_row8_col4,#T_48963_row8_col5,#T_48963_row8_col6,#T_48963_row8_col7,#T_48963_row9_col0,#T_48963_row9_col1,#T_48963_row9_col2,#T_48963_row9_col3,#T_48963_row9_col4,#T_48963_row9_col5,#T_48963_row9_col6,#T_48963_row9_col7,#T_48963_row10_col0,#T_48963_row10_col1,#T_48963_row10_col2,#T_48963_row10_col3,#T_48963_row10_col4,#T_48963_row10_col5,#T_48963_row10_col6,#T_48963_row10_col7,#T_48963_row11_col0,#T_48963_row11_col1,#T_48963_row11_col2,#T_48963_row11_col3,#T_48963_row11_col4,#T_48963_row11_col5,#T_48963_row11_col6,#T_48963_row11_col7,#T_48963_row12_col0,#T_48963_row12_col1,#T_48963_row12_col2,#T_48963_row12_col3,#T_48963_row12_col4,#T_48963_row12_col5,#T_48963_row12_col6,#T_48963_row12_col7,#T_48963_row13_col0,#T_48963_row13_col1,#T_48963_row13_col2,#T_48963_row13_col3,#T_48963_row13_col4,#T_48963_row13_col5,#T_48963_row13_col6,#T_48963_row13_col7{
#             text-align:  left;
#             text-align:  left;
#         }#T_48963_row0_col1,#T_48963_row0_col2,#T_48963_row0_col3,#T_48963_row0_col5,#T_48963_row0_col6,#T_48963_row0_col7,#T_48963_row3_col4{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_48963_row0_col8,#T_48963_row1_col8,#T_48963_row2_col8,#T_48963_row3_col8,#T_48963_row4_col8,#T_48963_row6_col8,#T_48963_row7_col8,#T_48963_row8_col8,#T_48963_row9_col8,#T_48963_row10_col8,#T_48963_row11_col8,#T_48963_row12_col8,#T_48963_row13_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }#T_48963_row5_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }</style><table id="T_48963_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>        <th class="col_heading level0 col8" >TT (Sec)</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_48963_level0_row0" class="row_heading level0 row0" >gbc</th>
#                         <td id="T_48963_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_48963_row0_col1" class="data row0 col1" >0.7926</td>
#                         <td id="T_48963_row0_col2" class="data row0 col2" >0.7309</td>
#                         <td id="T_48963_row0_col3" class="data row0 col3" >0.4314</td>
#                         <td id="T_48963_row0_col4" class="data row0 col4" >0.7693</td>
#                         <td id="T_48963_row0_col5" class="data row0 col5" >0.7445</td>
#                         <td id="T_48963_row0_col6" class="data row0 col6" >0.3398</td>
#                         <td id="T_48963_row0_col7" class="data row0 col7" >0.4088</td>
#                         <td id="T_48963_row0_col8" class="data row0 col8" >6.1160</td>
#             </tr>
#             <tr>
#                         <th id="T_48963_level0_row1" class="row_heading level0 row1" >rf</th>
#                         <td id="T_48963_row1_col0" class="data row1 col0" >Random Forest Classifier</td>
#                         <td id="T_48963_row1_col1" class="data row1 col1" >0.7878</td>
#                         <td id="T_48963_row1_col2" class="data row1 col2" >0.6792</td>
#                         <td id="T_48963_row1_col3" class="data row1 col3" >0.4087</td>
#                         <td id="T_48963_row1_col4" class="data row1 col4" >0.7603</td>
#                         <td id="T_48963_row1_col5" class="data row1 col5" >0.7384</td>
#                         <td id="T_48963_row1_col6" class="data row1 col6" >0.3217</td>
#                         <td id="T_48963_row1_col7" class="data row1 col7" >0.3882</td>
#                         <td id="T_48963_row1_col8" class="data row1 col8" >0.6240</td>
#             </tr>
#             <tr>
#                         <th id="T_48963_level0_row2" class="row_heading level0 row2" >dt</th>
#                         <td id="T_48963_row2_col0" class="data row2 col0" >Decision Tree Classifier</td>
#                         <td id="T_48963_row2_col1" class="data row2 col1" >0.7823</td>
#                         <td id="T_48963_row2_col2" class="data row2 col2" >0.6325</td>
#                         <td id="T_48963_row2_col3" class="data row2 col3" >0.4282</td>
#                         <td id="T_48963_row2_col4" class="data row2 col4" >0.7458</td>
#                         <td id="T_48963_row2_col5" class="data row2 col5" >0.7405</td>
#                         <td id="T_48963_row2_col6" class="data row2 col6" >0.3337</td>
#                         <td id="T_48963_row2_col7" class="data row2 col7" >0.3764</td>
#                         <td id="T_48963_row2_col8" class="data row2 col8" >0.3510</td>
#             </tr>
#             <tr>
#                         <th id="T_48963_level0_row3" class="row_heading level0 row3" >et</th>
#                         <td id="T_48963_row3_col0" class="data row3 col0" >Extra Trees Classifier</td>
#                         <td id="T_48963_row3_col1" class="data row3 col1" >0.7792</td>
#                         <td id="T_48963_row3_col2" class="data row3 col2" >0.6713</td>
#                         <td id="T_48963_row3_col3" class="data row3 col3" >0.3512</td>
#                         <td id="T_48963_row3_col4" class="data row3 col4" >0.7713</td>
#                         <td id="T_48963_row3_col5" class="data row3 col5" >0.7181</td>
#                         <td id="T_48963_row3_col6" class="data row3 col6" >0.2548</td>
#                         <td id="T_48963_row3_col7" class="data row3 col7" >0.3507</td>
#                         <td id="T_48963_row3_col8" class="data row3 col8" >1.2700</td>
#             </tr>
#             <tr>
#                         <th id="T_48963_level0_row4" class="row_heading level0 row4" >lightgbm</th>
#                         <td id="T_48963_row4_col0" class="data row4 col0" >Light Gradient Boosting Machine</td>
#                         <td id="T_48963_row4_col1" class="data row4 col1" >0.7766</td>
#                         <td id="T_48963_row4_col2" class="data row4 col2" >0.6978</td>
#                         <td id="T_48963_row4_col3" class="data row4 col3" >0.4052</td>
#                         <td id="T_48963_row4_col4" class="data row4 col4" >0.7327</td>
#                         <td id="T_48963_row4_col5" class="data row4 col5" >0.7345</td>
#                         <td id="T_48963_row4_co

# %%
evaluate_model(best_model)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
results = predict_model(best_model, test_set)
# Out:
# <style  type="text/css" >
# </style><table id="T_ac954_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ac954_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ac954_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#                         <td id="T_ac954_row0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_ac954_row0_col2" class="data row0 col2" >0.7438</td>
#                         <td id="T_ac954_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_ac954_row0_col4" class="data row0 col4" >0</td>
#                         <td id="T_ac954_row0_col5" class="data row0 col5" >0</td>
#                         <td id="T_ac954_row0_col6" class="data row0 col6" >0</td>
#                         <td id="T_ac954_row0_col7" class="data row0 col7" >0</td>
#             </tr>
#     </tbody></table>

# %%
correct_pred_count = 0
for index in range(len(results['Label'])):
    if results['Label'].iloc[index] == results['type'].iloc[index]:
        correct_pred_count += 1

print(correct_pred_count / len(results['Label'])) # About 78.8% prediction accuracy using a gradient boosting classifer
# Out:
# 0.7881059470264867

# %%
save_model(best_model, 'basic_GB_url_classifier')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=[],
#                                        ml_usecase='classification',
#                                        numerical_features=['unicode',
#                                                            'inequality', 'pipe',
#                                                            'semicolon',
#                                                            'curlybrace', 'caret',
#                                                            'consecutive_num',
#                                                            'hyphen',
#                                                            'underscore'],
#                                        target='type', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(cate...
#                                              learning_rate=0.1, loss='deviance',
#                                              max_depth=3, max_features=None,
#                                              max_leaf_nodes=None,
#                                              min_impurity_decrease=0.0,
#                                              min_impurity_split=None,
#                                              min_samples_leaf=1,
#                                              min_samples_split=2,
#                                              min_weight_fraction_leaf=0.0,
#                                              n_estimators=100,
#                                              n_iter_no_change=None,
#                                              presort='deprecated',
#                                              random_state=1025, subsample=1.0,
#                                              tol=0.0001, validation_fraction=0.1,
#                                              verbose=0, warm_start=False)]],
#           verbose=False),
#  'basic_GB_url_classifier.pkl')
