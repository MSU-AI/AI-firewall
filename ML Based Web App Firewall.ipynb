# %%
import pandas as pd
http_request_df = pd.read_csv("processed_urls.csv")

# %%
from pycaret.classification import *

# %%
clu1 = setup(data = http_request_df.loc[:4000,:], target='type', \
             numeric_features=['unicode', 'inequality', 'pipe', 'semicolon', 'curlybrace', 'caret'])
# Out:
# <style  type="text/css" >
# #T_bfaf3_row44_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_bfaf3_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_bfaf3_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_bfaf3_row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_bfaf3_row0_col1" class="data row0 col1" >8122</td>
#             </tr>
#             <tr>
#                         <th id="T_bfaf3_level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_bfaf3_row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_bfaf3_row1_col1" class="data row1 col1" >type</td>
#             </tr>
#             <tr>
# ...

# %%
best_models = compare_models()
# Out:
# <style  type="text/css" >
#     #T_1f803_ th {
#           text-align: left;
# ...

# %%
evaluate_model(best_models)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
predict_model(best_models, http_request_df.loc[0:4000,:])
# Out:
# <style  type="text/css" >
# </style><table id="T_4f139_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall</th>        <th class="col_heading level0 col4" >Prec.</th>        <th class="col_heading level0 col5" >F1</th>        <th class="col_heading level0 col6" >Kappa</th>        <th class="col_heading level0 col7" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_4f139_level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_4f139_row0_col0" class="data row0 col0" >SVM - Linear Kernel</td>
#                         <td id="T_4f139_row0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_4f139_row0_col2" class="data row0 col2" >0</td>
# ...

# %%
save_model(best_models, 'basic_svm_url_classifier')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        id_columns=['Unnamed: 0'],
#                                        ml_usecase='classification',
#                                        numerical_features=['unicode',
#                                                            'inequality', 'pipe',
#                                                            'semicolon',
#                                                            'curlybrace',
#                                                            'caret'],
#                                        target='type', time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_availab...
# ...
